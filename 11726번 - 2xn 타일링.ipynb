# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n=int(input())
def sol(n):
    if n == 1:
        return 1
    elif n == 2:
        return 2
    else:
        return sol(n-1) + sol(n-2)
ans = sol(n)%10007
print(ans)
# Out:
# 9
# 55

# %%
n=int(input())
lst = [0,1,2]
for i in range(n-2):
    lst.append(lst[-1]+lst[-2])
print(lst[n]%10007)
# Out:
# 9
# 55
