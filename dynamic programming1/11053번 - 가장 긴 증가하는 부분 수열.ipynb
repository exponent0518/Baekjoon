# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n=int(input())
A=list(map(int, input().split()))
l=[0]*n
for i in range(n):
    for j in range(i):
        if A[j] < A[i] and l[i] < l[j]:
            l[i]=l[j]
    l[i]+=1
print(max(l))
# Out:
# 8
# 1 2 4 1 2 3 4 5
# [1, 2, 3, 1, 2, 3, 4, 5]
