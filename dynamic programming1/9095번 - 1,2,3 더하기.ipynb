# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n=int(input())
lst=[]
for i in range(n):
    lst.append(int(input()))
def sol(n):
    if n == 1:
        return 1
    elif n == 2:
        return 2
    elif n == 3:
        return 4
    else:
        return sol(n-1)+sol(n-2)+sol(n-3)
for i in range(n):
    print(sol(lst[i]))
# Out:
# 3
# 4
# 7
# 10
# 7
# 44
# 274
