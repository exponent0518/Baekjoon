# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n=int(input())
A=list(map(int, input().split()))

d=[1]*n
d[0]=A[0]
for i in range(1,n):
    for j in range(i):
        if A[j]<A[i]:
            d[i]=max(d[i], d[j]+A[i])
        else:
            d[i]=max(d[i], A[i])

print(max(d))
# Out:
# 10
# 1 100 2 50 60 3 5 6 7 8
# 113
