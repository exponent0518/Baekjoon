# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())
lst = []
for i in range(n):
    lst.append(int(input()))
lst.sort(reverse=True)

lst2 = []
for i in range(n):
    lst2.append(lst[i] * (i + 1))
print(max(lst2))
# Out:
# 2
# 10
# 15
# 20
