# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())
lst = list(map(int, input().split()))
lst.sort()
cnt = 0
l = len(lst)
for i in range(len(lst)):
    cnt += lst[i] * l
    l -= 1
print(cnt)
# Out:
# 5
# 3 1 4 3 2
# 32
