# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
n=int(input())
l=[]
for i in range(n):
    l.append(str(input()))
k=[]
for i in range(n):
    k.append(l[i].split('.')[1])

dic={}
for i in k:
    try: dic[i] += 1
    except: dic[i]=1

final = sorted(dic.items())
for i in range(len(final)):
    print(final[i][0],final[i][1])
# Out:
# 8
# sbrus.txt
# spc.spc
# acm.icpc
# korea.icpc
# sample.txt
# hello.world
# sogang.spc
# example.txt
# ['txt', 'spc', 'icpc', 'icpc', 'txt', 'world', 'spc', 'txt']
# {'txt': 3, 'spc': 2, 'icpc': 2, 'world': 1}
# icpc 2
# spc 2
# txt 3
# world 1

# %%
# Out:
# ['txt', 'spc', 'icpc', 'icpc', 'txt', 'world', 'spc', 'txt']

# %%
# Out:
# {'txt': 3, 'spc': 2, 'icpc': 2, 'world': 1}

# %%
# Out:
# icpc 2
# spc 2
# txt 3
# world 1
